# %% [markdown]
# <a href="https://colab.research.google.com/github/datascience-1100/Loops-in-Python/blob/main/While_loops_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# While Loop

# %%
#while condition is true:
# code block to execute

# %%
for i in range (2,6):
  print('Me')
# Out:
# Me
# Me
# Me
# Me

# %%
name= input("Enter your name")

while name =='':
  print("Please provide a name")

print(name)
# Out:
# Streaming output truncated to the last 5000 lines.
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# Please provide a name
# ...

# %%
#while condition is true:
   execute codes

# %%
name= input("Enter your name")

while not name =='Quit':
  print("Please provide a name")
  name=input("Enter your name")

print(name)
# Out:
# Enter your namemike
# Please provide a name
# Enter your name
# Please provide a name
# Enter your name
# Please provide a name
# Enter your namehdihfdish
# Please provide a name
# Enter your nameQuit
# Quit

# %%
i=int(input("Enter any number"))
while i<=5:
 print(i)
 i=i+1
print("the end")
# Out:
# Enter any number3
# 3
# 4
# 5
# the end

# %%
#Printing in reverse order
i=5
while i>1:
 print(i)
 i=i-1
print("the end")

# %%
#Diff between for and while loop
#When we do not know how many times we need to repeat  a block of code.
#It keeps repeating as long as Boolean expression contimues to be true

# %%
#While loop with if-else statement
#To find the numbers which are below 20
a=[2,40,6,25,10]
i=0
x=len(a)
while i<x:
  if a[i]<20:
    print(a[i])
    i=i+1
  else:
    i=i+1

# %%
#Add 2 with all the numbers in the list
a = [2, 40, 6, 25, 10]
j = []
i = 0

while i < len(a):
    modified_num = a[i] + 2
    j.append(modified_num)
    i += 1

print(j)

# %%
# Flow control with while loop
num = 10
while num > 0:
    print(num)
    num -= 2

# %%
# Example 4: Infinite loop
while True:
    print("This is an infinite loop!")
# Out:
# Streaming output truncated to the last 5000 lines.
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# This is an infinite loop!
# ...

# %%
# Example 5: Nesting while loops
row = 1
while row <= 3:
    col = 1
    while col <= 3:
        print(row, col)
        col += 1
    row += 1

# %%
# Example 6: Using break and continue in a while loop

#break means the loop will stop execution without letting the other statements execute
#continue will continue the loop without letting the other statements execute
num = 1
while num <= 10:
    if num == 5:
        break  # Exit the loop when num equals 5
    print(num)
    num += 1

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
